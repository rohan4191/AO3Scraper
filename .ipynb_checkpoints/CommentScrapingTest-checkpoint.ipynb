# %%
from bs4 import BeautifulSoup
import requests
from time import sleep

# %%
# returns ID of the comment and saves it to database
def get_single_comment(ficid, comment, parentID):
    print("Single comment")
    # Find username
    if comment.find('h4', class_='heading byline').find('a'):
        username = comment.find('h4', class_='heading byline').find('a').contents[0]
    else:
        username = comment.find('h4', class_='heading byline').contents[0]

    # get chapter number
    # each comment has header "username on Chapter x" so get that text and split on spaces to isolate number
    # if single chap fic, no header, so default to 1
    header = comment.find("span", class_="parent")
    if header:
        chapternumber = int(header.text.split(" ")[-1])
    else:
        chapternumber = 1
        
    # Get datetime
    datetime = comment.find('h4', class_='heading byline').find('span', class_="posted datetime").contents
    remove = ['\n', ' ']
    dateObj = {}

    for item in datetime:
        if item not in remove:
            itemClass = item['class'][0]
            itemValue = item.contents[0]
            dateObj[itemClass] = itemValue

    # Get comment id
    commentid = comment['id'].split('_')[1]

    # Get direct comment text
    text = comment.findAll("p")
    text = [str(p).replace("<br/>", "\n").replace("<p>", "").replace("</p>", "") for p in text]
    text = "\n".join(text)

    # print out comment data
    # TODO: enter data in SQL DB
    
    commentData = (ficid, chapternumber, username, dateObj, commentid, parentID, text)
    print(commentData)
    return commentid

# %%
# recursively loops over thread of comments
def get_comment_thread(ficid, thread, parentID):
    print("comment thread")
    
    # get individual comments
    comments = thread.findChildren("li", recursive=False)

    # track what id the parent comment should be
    newParentID = parentID
    for c, comment in enumerate(comments):
        # if only attr is class=commant, it's a collapsed thread we need to open
        if comment.attrs = {'class': ['comment']}:
            url = "http://archiveofourown.org" + comment.find("a")["href"]
            status = 429
            while 429 == status:
                req = requests.get(url)
                status = req.status_code
                if 429 == status:
                    print("Request answered with Status-Code 429")
                    print("Trying again in 1 minute...")
                    sleep(60)
            # for other errors, halt scraping
            if 400 <= status:
                print("Error:", status, ", halting scraping on fic", ficid)
                return
            thread = soup.find("ol", class_="thread")
            get_comment_thread(ficid, thread, newParentID)
            
        # if comments has attrs, it's a single comment
        else if comment.attrs != {}:
            # if we encounter a thread, that thread's parent will always be the most recent single comment
            # so maintain the ID of most recent single comment as parent ID
            newParentID = get_single_comment(ficid, comment, parentID)
            
        # if no attrs, it's a thread -- meaning it is a child of the previous comment
        else:
            thread = comment.findChild("ol")
            get_comment_thread(ficid, thread, newParentID)

# %%
def get_comment_page(ficid, page_num):
    url = 'http://archiveofourown.org/works/'+str(ficid)+'?view_adult=true&amp;view_full_work=true&show_comments=true&page='\
    + str(page_num)
    print("URL:", url)
    
    status = 429
    while 429 == status:
        req = requests.get(url)
        status = req.status_code
        if 429 == status:
            print("Request answered with Status-Code 429")
            print("Trying again in 1 minute...")
            sleep(60)
    # for other errors, write out to csv and pass
    if 400 <= status:
        print("Error:", status, ", halting scraping on page", page_num)
        return
    
    src = req.text
    soup = BeautifulSoup(src, 'html.parser')
    
    thread = soup.find('ol', class_ = 'thread')
    if not thread:
        print(f"Fic {ficid} has no comments on page {pagenum}")
        return
    
    get_comment_thread(ficid, thread, 0)

# %%
def get_all_comments(ficid):
    url = 'http://archiveofourown.org/works/'+str(ficid)+'?view_adult=true&amp;view_full_work=true&show_comments=true'
    
    status = 429
    while 429 == status:
        req = requests.get(url)
        status = req.status_code
        if 429 == status:
            print("Request answered with Status-Code 429")
            print("Trying again in 1 minute...")
            sleep(60)
    # for other errors, write out to csv and pass
    if 400 <= status:
        print("Error:", status, ", halting scraping on fic", ficid)
        return
    
    src = req.text
    soup = BeautifulSoup(src, 'html.parser')
    
    # check to see if enough comments for multiple pages
    if (soup.find('ol', class_='pagination actions')):
        # get max page num
        numpages = int(soup.find('ol', class_='pagination actions').findChildren("li", recursive=False)[-2].text)
        # get comments for each page
        for i in range(numpages):
            get_comment_page(ficid, i+1)
            
    # if only one page of comments
    else:
        get_comment_page(ficid, 1)

# %%
get_comment_page(10057010, 1)
# Out:
# URL: http://archiveofourown.org/works/10057010?view_adult=true&amp;view_full_work=true&show_comments=true&page=1
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Fri', 'date': '03', 'month': 'Mar', 'year': '2017', 'time': '12:36AM', 'timezone': 'UTC'}, '97071584', 0, "i really like your writing, and the story! i'm excited to read the rest of it :)")
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Tue', 'date': '18', 'month': 'Jul', 'year': '2023', 'time': '09:52PM', 'timezone': 'UTC'}, '671875867', '97071584', 'Honestly just here today to ask you how does it feel to be the first to comment on a fic that, as far as I know, turned out to be the one with the most hits on the whole ao3')
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Fri', 'date': '21', 'month': 'Jul', 'year': '2023', 'time': '06:34AM', 'timezone': 'UTC'}, '672704722', '671875867', 'ha')
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '04', 'month': 'Sep', 'year': '2023', 'time': '01:50PM', 'timezone': 'UTC'}, '688155103', '671875867', 'Atyd is the one with the most hits???? Fr???? I didn’t know that')
# comment thread
# Single comment
# (10057010, 1, 'seiworf', {'day': 'Wed', 'date': '06', 'month': 'Dec', 'year': '2023', 'time': '09:06PM', 'timezone': 'UTC'}, '718068046', '688155103', "girl it has over 12 MILLION hits!! hahaha it's insane &lt;3")
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '04', 'month': 'Sep', 'year': '2023', 'time': '01:51PM', 'timezone': 'UTC'}, '688155394', '671875867', 'I wish Taylor swift sill answered us on these comments 😭😭😭😭')
# comment thread
# Single comment
# (10057010, 1, 'avatarazutara', {'day': 'Sat', 'date': '28', 'month': 'Oct', 'year': '2023', 'time': '03:55AM', 'timezone': 'UTC'}, '705507193', '688155394', 'omfg 😂')
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '11', 'month': 'Dec', 'year': '2023', 'time': '11:26PM', 'timezone': 'UTC'}, '719663482', '688155394', 'wait wdym?')
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '12', 'month': 'Feb', 'year': '2024', 'time': '03:35PM', 'timezone': 'UTC'}, '740899906', '719663482', 'some people think that mskingbean89 is taylor swift')
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Tue', 'date': '13', 'month': 'Feb', 'year': '2024', 'time': '04:36PM', 'timezone': 'UTC'}, '741277471', '740899906', 'nobody actually thinks that LMFAO it’s just an inside joke')
# Single comment
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 get_comment_page(10057010, 1)
#
# Cell In [4], line 27, in get_comment_page(ficid, page_num)
#      24     print(f"Fic {ficid} has no comments on page {pagenum}")
#      25     return
# ---> 27 get_comment_thread(ficid, thread, 0)
#
# Cell In [3], line 20, in get_comment_thread(ficid, thread, parentID)
#      17 # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18 else:
#      19     thread = comment.findChild("ol")
# ---> 20     get_comment_thread(ficid, thread, newParentID)
#
# Cell In [3], line 20, in get_comment_thread(ficid, thread, parentID)
#      17 # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18 else:
#      19     thread = comment.findChild("ol")
# ---> 20     get_comment_thread(ficid, thread, newParentID)
#
#     [... skipping similar frames: get_comment_thread at line 20 (2 times)]
#
# Cell In [3], line 20, in get_comment_thread(ficid, thread, parentID)
#      17 # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18 else:
#      19     thread = comment.findChild("ol")
# ---> 20     get_comment_thread(ficid, thread, newParentID)
#
# Cell In [3], line 15, in get_comment_thread(ficid, thread, parentID)
#      10 for c, comment in enumerate(comments):
#      11     # if comments has attrs, it's a single comment
#      12     if comment.attrs != {}:
#      13         # if we encounter a thread, that thread's parent will always be the most recent single comment
#      14         # so maintain the ID of most recent single comment as parent ID
# ---> 15         newParentID = get_single_comment(ficid, comment, parentID)
#      17     # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18     else:
#      19         thread = comment.findChild("ol")
#
# Cell In [2], line 5, in get_single_comment(ficid, comment, parentID)
#       3 print("Single comment")
#       4 # Find username
# ----> 5 if comment.find('h4', class_='heading byline').find('a'):
#       6     username = comment.find('h4', class_='heading byline').find('a').contents[0]
#       7 else:
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
get_all_comments(10057010)
# Out:
# Request answered with Status-Code 429
# Trying again in 1 minute...
# URL: http://archiveofourown.org/works/10057010?view_adult=true&amp;view_full_work=true&show_comments=true&page=1
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Fri', 'date': '03', 'month': 'Mar', 'year': '2017', 'time': '12:36AM', 'timezone': 'UTC'}, '97071584', 0, "i really like your writing, and the story! i'm excited to read the rest of it :)")
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Tue', 'date': '18', 'month': 'Jul', 'year': '2023', 'time': '09:52PM', 'timezone': 'UTC'}, '671875867', '97071584', 'Honestly just here today to ask you how does it feel to be the first to comment on a fic that, as far as I know, turned out to be the one with the most hits on the whole ao3')
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Fri', 'date': '21', 'month': 'Jul', 'year': '2023', 'time': '06:34AM', 'timezone': 'UTC'}, '672704722', '671875867', 'ha')
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '04', 'month': 'Sep', 'year': '2023', 'time': '01:50PM', 'timezone': 'UTC'}, '688155103', '671875867', 'Atyd is the one with the most hits???? Fr???? I didn’t know that')
# comment thread
# Single comment
# (10057010, 1, 'seiworf', {'day': 'Wed', 'date': '06', 'month': 'Dec', 'year': '2023', 'time': '09:06PM', 'timezone': 'UTC'}, '718068046', '688155103', "girl it has over 12 MILLION hits!! hahaha it's insane &lt;3")
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '04', 'month': 'Sep', 'year': '2023', 'time': '01:51PM', 'timezone': 'UTC'}, '688155394', '671875867', 'I wish Taylor swift sill answered us on these comments 😭😭😭😭')
# comment thread
# Single comment
# (10057010, 1, 'avatarazutara', {'day': 'Sat', 'date': '28', 'month': 'Oct', 'year': '2023', 'time': '03:55AM', 'timezone': 'UTC'}, '705507193', '688155394', 'omfg 😂')
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '11', 'month': 'Dec', 'year': '2023', 'time': '11:26PM', 'timezone': 'UTC'}, '719663482', '688155394', 'wait wdym?')
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Mon', 'date': '12', 'month': 'Feb', 'year': '2024', 'time': '03:35PM', 'timezone': 'UTC'}, '740899906', '719663482', 'some people think that mskingbean89 is taylor swift')
# comment thread
# Single comment
# (10057010, 1, '\n', {'day': 'Tue', 'date': '13', 'month': 'Feb', 'year': '2024', 'time': '04:36PM', 'timezone': 'UTC'}, '741277471', '740899906', 'nobody actually thinks that LMFAO it’s just an inside joke')
# Single comment
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 get_all_comments(10057010)
#
# Cell In [7], line 26, in get_all_comments(ficid)
#      24     # get comments for each page
#      25     for i in range(numpages):
# ---> 26         get_comment_page(ficid, i+1)
#      28 # if only one page of comments
#      29 else:
#      30     get_comment_page(ficid, 1)
#
# Cell In [4], line 27, in get_comment_page(ficid, page_num)
#      24     print(f"Fic {ficid} has no comments on page {pagenum}")
#      25     return
# ---> 27 get_comment_thread(ficid, thread, 0)
#
# Cell In [3], line 20, in get_comment_thread(ficid, thread, parentID)
#      17 # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18 else:
#      19     thread = comment.findChild("ol")
# ---> 20     get_comment_thread(ficid, thread, newParentID)
#
# Cell In [3], line 20, in get_comment_thread(ficid, thread, parentID)
#      17 # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18 else:
#      19     thread = comment.findChild("ol")
# ---> 20     get_comment_thread(ficid, thread, newParentID)
#
#     [... skipping similar frames: get_comment_thread at line 20 (2 times)]
#
# Cell In [3], line 20, in get_comment_thread(ficid, thread, parentID)
#      17 # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18 else:
#      19     thread = comment.findChild("ol")
# ---> 20     get_comment_thread(ficid, thread, newParentID)
#
# Cell In [3], line 15, in get_comment_thread(ficid, thread, parentID)
#      10 for c, comment in enumerate(comments):
#      11     # if comments has attrs, it's a single comment
#      12     if comment.attrs != {}:
#      13         # if we encounter a thread, that thread's parent will always be the most recent single comment
#      14         # so maintain the ID of most recent single comment as parent ID
# ---> 15         newParentID = get_single_comment(ficid, comment, parentID)
#      17     # if no attrs, it's a thread -- meaning it is a child of the previous comment
#      18     else:
#      19         thread = comment.findChild("ol")
#
# Cell In [2], line 5, in get_single_comment(ficid, comment, parentID)
#       3 print("Single comment")
#       4 # Find username
# ----> 5 if comment.find('h4', class_='heading byline').find('a'):
#       6     username = comment.find('h4', class_='heading byline').find('a').contents[0]
#       7 else:
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
fic_id = 10057010
url = 'http://archiveofourown.org/works/'+str(fic_id)+'?view_adult=true&amp;view_full_work=true&show_comments=true&page=1'
req = requests.get(url, "")
src = req.text
soup = BeautifulSoup(src, 'html.parser')

print("URL:", url)
# Out:
# URL: http://archiveofourown.org/works/10057010?view_adult=true&amp;view_full_work=true&show_comments=true&page=1

# %%
def get_thread(comment):
    return comment.find("ol", class_="thread").findChildren("li", recursive=False)

# %%
comments = get_thread(soup)
comments[1]
# Out:
# <li>
# <ol class="thread">
# <li class="even guest comment group" id="comment_671875867" role="article">
# <h4 class="heading byline">
# <span>lololol</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Tuesday">Tue</abbr> <span class="date">18</span>
# <abbr class="month" title="July">Jul</abbr> <span class="year">2023</span>
# <span class="time">09:52PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>Honestly just here today to ask you how does it feel to be the first to comment on a fic that, as far as I know, turned out to be the one with the most hits on the whole ao3</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_671875867">
# <li id="add_comment_reply_link_671875867"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=671875867&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/671875867">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_671875867" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_671875867" style="display: none;">
# </div>
# </li>
# <li>
# <ol class="thread">
# <li class="odd guest comment group" id="comment_672704722" role="article">
# <h4 class="heading byline">
# <span>noxx</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Friday">Fri</abbr> <span class="date">21</span>
# <abbr class="month" title="July">Jul</abbr> <span class="year">2023</span>
# <span class="time">06:34AM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>ha</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_672704722">
# <li id="add_comment_reply_link_672704722"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=672704722&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/672704722">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_672704722" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_672704722" style="display: none;">
# </div>
# </li>
# <li class="even guest comment group" id="comment_688155103" role="article">
# <h4 class="heading byline">
# <span>Gabs</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">04</span>
# <abbr class="month" title="September">Sep</abbr> <span class="year">2023</span>
# <span class="time">01:50PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>Atyd is the one with the most hits???? Fr???? I didn’t know that</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_688155103">
# <li id="add_comment_reply_link_688155103"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=688155103&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/688155103">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_688155103" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_688155103" style="display: none;">
# </div>
# </li>
# <li>
# <ol class="thread">
# <li class="odd comment group user-17732734" id="comment_718068046" role="article">
# <h4 class="heading byline">
# <a href="/users/seiworf/pseuds/seiworf">seiworf</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Wednesday">Wed</abbr> <span class="date">06</span>
# <abbr class="month" title="December">Dec</abbr> <span class="year">2023</span>
# <span class="time">09:06PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/seiworf/pseuds/seiworf"><img alt="" class="icon" src="https://s3.amazonaws.com/otw-ao3-icons/icons/18732808/standard.jpeg?1685969639"/></a>
# </div>
# <blockquote class="userstuff">
# <p>girl it has over 12 MILLION hits!! hahaha it's insane &lt;3</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_718068046">
# <li id="add_comment_reply_link_718068046"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=718068046&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/718068046">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_718068046" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_718068046" style="display: none;">
# </div>
# </li>
# </ol>
# </li>
# <li class="even guest comment group" id="comment_688155394" role="article">
# <h4 class="heading byline">
# <span>Gabriella</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">04</span>
# <abbr class="month" title="September">Sep</abbr> <span class="year">2023</span>
# <span class="time">01:51PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>I wish Taylor swift sill answered us on these comments 😭😭😭😭</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_688155394">
# <li id="add_comment_reply_link_688155394"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=688155394&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/688155394">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_688155394" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_688155394" style="display: none;">
# </div>
# </li>
# <li>
# <ol class="thread">
# <li class="odd comment group user-4407885" id="comment_705507193" role="article">
# <h4 class="heading byline">
# <a href="/users/avatarazutara/pseuds/avatarazutara">avatarazutara</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Saturday">Sat</abbr> <span class="date">28</span>
# <abbr class="month" title="October">Oct</abbr> <span class="year">2023</span>
# <span class="time">03:55AM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/avatarazutara/pseuds/avatarazutara"><img alt="" class="icon" src="https://s3.amazonaws.com/otw-ao3-icons/icons/4737675/standard.jpeg?1638696085"/></a>
# </div>
# <blockquote class="userstuff">
# <p>omfg 😂</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_705507193">
# <li id="add_comment_reply_link_705507193"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=705507193&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/705507193">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_705507193" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_705507193" style="display: none;">
# </div>
# </li>
# <li class="even guest comment group" id="comment_719663482" role="article">
# <h4 class="heading byline">
# <span>stella</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">11</span>
# <abbr class="month" title="December">Dec</abbr> <span class="year">2023</span>
# <span class="time">11:26PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>wait wdym?</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_719663482">
# <li id="add_comment_reply_link_719663482"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=719663482&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/719663482">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_719663482" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_719663482" style="display: none;">
# </div>
# </li>
# <li>
# <ol class="thread">
# <li class="odd guest comment group" id="comment_740899906" role="article">
# <h4 class="heading byline">
# <span>holly</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">12</span>
# <abbr class="month" title="February">Feb</abbr> <span class="year">2024</span>
# <span class="time">03:35PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>some people think that mskingbean89 is taylor swift</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_740899906">
# <li id="add_comment_reply_link_740899906"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=740899906&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/740899906">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_740899906" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_740899906" style="display: none;">
# </div>
# </li>
# <li>
# <ol class="thread">
# <li class="even guest comment group" id="comment_741277471" role="article">
# <h4 class="heading byline">
# <span>anna</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Tuesday">Tue</abbr> <span class="date">13</span>
# <abbr class="month" title="February">Feb</abbr> <span class="year">2024</span>
# <span class="time">04:36PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>nobody actually thinks that LMFAO it’s just an inside joke</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_741277471">
# <li id="add_comment_reply_link_741277471"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=741277471&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/741277471">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_741277471" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_741277471" style="display: none;">
# </div>
# </li>
# <li class="comment"><p>(<a href="/comments/741277471">2 more comments in this thread</a>)</p></li>
# </ol>
# </li>
# </ol>
# </li>
# <li class="odd guest comment group" id="comment_756354380" role="article">
# <h4 class="heading byline">
# <span>Melissa</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Wednesday">Wed</abbr> <span class="date">27</span>
# <abbr class="month" title="March">Mar</abbr> <span class="year">2024</span>
# <span class="time">08:05AM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>REAAALL😭</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_756354380">
# <li id="add_comment_reply_link_756354380"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=756354380&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/756354380">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_756354380" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_756354380" style="display: none;">
# </div>
# </li>
# <li class="even comment group user-21375931" id="comment_776549551" role="article">
# <h4 class="heading byline">
# <a href="/users/dearestlyli/pseuds/dearestlyli">dearestlyli</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Wednesday">Wed</abbr> <span class="date">22</span>
# <abbr class="month" title="May">May</abbr> <span class="year">2024</span>
# <span class="time">03:56PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/dearestlyli/pseuds/dearestlyli"><img alt="" class="icon" src="/images/skins/iconsets/default/icon_user.png"/></a>
# </div>
# <blockquote class="userstuff">
# <p>real</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_776549551">
# <li id="add_comment_reply_link_776549551"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=776549551&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/776549551">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_776549551" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_776549551" style="display: none;">
# </div>
# </li>
# </ol>
# </li>
# <li class="odd comment group user-17220913" id="comment_707690485" role="article">
# <h4 class="heading byline">
# <a href="/users/ladyofwolfstar/pseuds/ladyofwolfstar">ladyofwolfstar</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Friday">Fri</abbr> <span class="date">03</span>
# <abbr class="month" title="November">Nov</abbr> <span class="year">2023</span>
# <span class="time">11:37PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/ladyofwolfstar/pseuds/ladyofwolfstar"><img alt="" class="icon" src="https://s3.amazonaws.com/otw-ao3-icons/icons/18196786/standard.jpg?1704927954"/></a>
# </div>
# <blockquote class="userstuff">
# <p>I know like it must be so surreal being the first person to show support to the bible of the marauders fandom</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_707690485">
# <li id="add_comment_reply_link_707690485"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=707690485&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/707690485">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_707690485" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_707690485" style="display: none;">
# </div>
# </li>
# </ol>
# </li>
# <li class="even guest comment group" id="comment_725746846" role="article">
# <h4 class="heading byline">
# <span>strangestrealm</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Sunday">Sun</abbr> <span class="date">31</span>
# <abbr class="month" title="December">Dec</abbr> <span class="year">2023</span>
# <span class="time">01:26AM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>here for my annual reread but how does it feel to be the first person to comment on THE marauders fic</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_725746846">
# <li id="add_comment_reply_link_725746846"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=725746846&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/725746846">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_725746846" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_725746846" style="display: none;">
# </div>
# </li>
# <li class="odd comment group user-7746595" id="comment_754420762" role="article">
# <h4 class="heading byline">
# <a href="/users/cloudylettuce/pseuds/cloudylettuce">cloudylettuce</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Thursday">Thu</abbr> <span class="date">21</span>
# <abbr class="month" title="March">Mar</abbr> <span class="year">2024</span>
# <span class="time">07:07PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/cloudylettuce/pseuds/cloudylettuce"><img alt="" class="icon" src="https://s3.amazonaws.com/otw-ao3-icons/icons/8249818/standard.jpeg?1708123245"/></a>
# </div>
# <blockquote class="userstuff">
# <p>actually if i was the first person to comment on this fic i wouldn’t shut up about it</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_754420762">
# <li id="add_comment_reply_link_754420762"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=754420762&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/754420762">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_754420762" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_754420762" style="display: none;">
# </div>
# </li>
# <li class="even comment group user-18889381" id="comment_772547398" role="article">
# <h4 class="heading byline">
# <a href="/users/A_fish_in_a_fancy_hat/pseuds/A_fish_in_a_fancy_hat">A_fish_in_a_fancy_hat</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Friday">Fri</abbr> <span class="date">10</span>
# <abbr class="month" title="May">May</abbr> <span class="year">2024</span>
# <span class="time">09:26PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/A_fish_in_a_fancy_hat/pseuds/A_fish_in_a_fancy_hat"><img alt="" class="icon" src="https://s3.amazonaws.com/otw-ao3-icons/icons/19936876/standard.jpeg?1699985344"/></a>
# </div>
# <blockquote class="userstuff">
# <p>You were the first commenter on a fic like this. Be proud.</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_772547398">
# <li id="add_comment_reply_link_772547398"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=772547398&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/772547398">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_772547398" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_772547398" style="display: none;">
# </div>
# </li>
# </ol>
# </li>

# %%
comments = get_thread(comments[1])
comments[0]
# Out:
# <li class="even guest comment group" id="comment_671875867" role="article">
# <h4 class="heading byline">
# <span>lololol</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Tuesday">Tue</abbr> <span class="date">18</span>
# <abbr class="month" title="July">Jul</abbr> <span class="year">2023</span>
# <span class="time">09:52PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>Honestly just here today to ask you how does it feel to be the first to comment on a fic that, as far as I know, turned out to be the one with the most hits on the whole ao3</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_671875867">
# <li id="add_comment_reply_link_671875867"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=671875867&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/671875867">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_671875867" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_671875867" style="display: none;">
# </div>
# </li>

# %%
comments = get_thread(comments[1])
comments[4]
# Out:
# <li>
# <ol class="thread">
# <li class="odd comment group user-4407885" id="comment_705507193" role="article">
# <h4 class="heading byline">
# <a href="/users/avatarazutara/pseuds/avatarazutara">avatarazutara</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Saturday">Sat</abbr> <span class="date">28</span>
# <abbr class="month" title="October">Oct</abbr> <span class="year">2023</span>
# <span class="time">03:55AM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/avatarazutara/pseuds/avatarazutara"><img alt="" class="icon" src="https://s3.amazonaws.com/otw-ao3-icons/icons/4737675/standard.jpeg?1638696085"/></a>
# </div>
# <blockquote class="userstuff">
# <p>omfg 😂</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_705507193">
# <li id="add_comment_reply_link_705507193"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=705507193&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/705507193">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_705507193" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_705507193" style="display: none;">
# </div>
# </li>
# <li class="even guest comment group" id="comment_719663482" role="article">
# <h4 class="heading byline">
# <span>stella</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">11</span>
# <abbr class="month" title="December">Dec</abbr> <span class="year">2023</span>
# <span class="time">11:26PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>wait wdym?</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_719663482">
# <li id="add_comment_reply_link_719663482"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=719663482&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/719663482">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_719663482" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_719663482" style="display: none;">
# </div>
# </li>
# <li>
# <ol class="thread">
# <li class="odd guest comment group" id="comment_740899906" role="article">
# <h4 class="heading byline">
# <span>holly</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">12</span>
# <abbr class="month" title="February">Feb</abbr> <span class="year">2024</span>
# <span class="time">03:35PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>some people think that mskingbean89 is taylor swift</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_740899906">
# <li id="add_comment_reply_link_740899906"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=740899906&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/740899906">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_740899906" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_740899906" style="display: none;">
# </div>
# </li>
# <li>
# <ol class="thread">
# <li class="even guest comment group" id="comment_741277471" role="article">
# <h4 class="heading byline">
# <span>anna</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Tuesday">Tue</abbr> <span class="date">13</span>
# <abbr class="month" title="February">Feb</abbr> <span class="year">2024</span>
# <span class="time">04:36PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>nobody actually thinks that LMFAO it’s just an inside joke</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_741277471">
# <li id="add_comment_reply_link_741277471"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=741277471&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/741277471">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_741277471" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_741277471" style="display: none;">
# </div>
# </li>
# <li class="comment"><p>(<a href="/comments/741277471">2 more comments in this thread</a>)</p></li>
# </ol>
# </li>
# </ol>
# </li>
# <li class="odd guest comment group" id="comment_756354380" role="article">
# <h4 class="heading byline">
# <span>Melissa</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Wednesday">Wed</abbr> <span class="date">27</span>
# <abbr class="month" title="March">Mar</abbr> <span class="year">2024</span>
# <span class="time">08:05AM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>REAAALL😭</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_756354380">
# <li id="add_comment_reply_link_756354380"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=756354380&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/756354380">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_756354380" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_756354380" style="display: none;">
# </div>
# </li>
# <li class="even comment group user-21375931" id="comment_776549551" role="article">
# <h4 class="heading byline">
# <a href="/users/dearestlyli/pseuds/dearestlyli">dearestlyli</a>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Wednesday">Wed</abbr> <span class="date">22</span>
# <abbr class="month" title="May">May</abbr> <span class="year">2024</span>
# <span class="time">03:56PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <a href="/users/dearestlyli/pseuds/dearestlyli"><img alt="" class="icon" src="/images/skins/iconsets/default/icon_user.png"/></a>
# </div>
# <blockquote class="userstuff">
# <p>real</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_776549551">
# <li id="add_comment_reply_link_776549551"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=776549551&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/776549551">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_776549551" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_776549551" style="display: none;">
# </div>
# </li>
# </ol>
# </li>

# %%
comments = get_thread(comments[4])
comments[2]
# Out:
# <li class="even guest comment group" id="comment_719663482" role="article">
# <h4 class="heading byline">
# <span>stella</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">11</span>
# <abbr class="month" title="December">Dec</abbr> <span class="year">2023</span>
# <span class="time">11:26PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>wait wdym?</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_719663482">
# <li id="add_comment_reply_link_719663482"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=719663482&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/719663482">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_719663482" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_719663482" style="display: none;">
# </div>
# </li>

# %%
comments = get_thread(comments[2])
comments[1]
# Out:
# <li class="odd guest comment group" id="comment_740899906" role="article">
# <h4 class="heading byline">
# <span>holly</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Monday">Mon</abbr> <span class="date">12</span>
# <abbr class="month" title="February">Feb</abbr> <span class="year">2024</span>
# <span class="time">03:35PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>some people think that mskingbean89 is taylor swift</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_740899906">
# <li id="add_comment_reply_link_740899906"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=740899906&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/740899906">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_740899906" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_740899906" style="display: none;">
# </div>
# </li>

# %%
comments = get_thread(comments[1])
comments[0]
# Out:
# <li class="even guest comment group" id="comment_741277471" role="article">
# <h4 class="heading byline">
# <span>anna</span><span class="role"> (Guest)</span>
# <span class="parent">
# on Chapter 1
# </span>
# <span class="posted datetime">
# <abbr class="day" title="Tuesday">Tue</abbr> <span class="date">13</span>
# <abbr class="month" title="February">Feb</abbr> <span class="year">2024</span>
# <span class="time">04:36PM</span> <abbr class="timezone" title="UTC">UTC</abbr>
# </span>
# </h4>
# <div class="icon">
# <span class="visitor icon"></span>
# </div>
# <blockquote class="userstuff">
# <p>nobody actually thinks that LMFAO it’s just an inside joke</p>
# </blockquote>
# <h5 class="landmark heading">Comment Actions</h5>
# <ul class="actions" id="navigation_for_comment_741277471">
# <li id="add_comment_reply_link_741277471"><a data-remote="true" href="/comments/add_comment_reply?chapter_id=22409387&amp;id=741277471&amp;page=1&amp;view_full_work=true">Reply</a></li>
# <li><a href="/comments/741277471">Thread</a></li>
# <li>
# <a href="/comments/97071584">Parent Thread</a>
# </li>
# </ul>
# <div id="delete_comment_placeholder_741277471" style="display:none;">
# </div>
# <div id="add_comment_reply_placeholder_741277471" style="display: none;">
# </div>
# </li>

# %%
comments[1].attrs == {'class': ['comment']}
# Out:
# True

# %%
comments[1].find("a")["href"]
# Out:
# '/comments/741277471'

# %%
url = "http://archiveofourown.org" + comments[1].find("a")["href"]
req = requests.get(url, "")
src = req.text
soup = BeautifulSoup(src, 'html.parser')
thread = soup.find("ol", class_="thread")

# %%
get_comment_thread(777, thread, 999)
# Out:
# comment thread
# Single comment
# (777, 1, '\n', {'day': 'Tue', 'date': '13', 'month': 'Feb', 'year': '2024', 'time': '04:36PM', 'timezone': 'UTC'}, '741277471', 999, 'nobody actually thinks that LMFAO it’s just an inside joke')
# comment thread
# Single comment
# (777, 1, 'ImComplicatedAF23', {'day': 'Mon', 'date': '19', 'month': 'Feb', 'year': '2024', 'time': '08:10AM', 'timezone': 'UTC'}, '743364499', '741277471', 'Yes we actually think that')
# Single comment
# (777, 1, '\n', {'day': 'Thu', 'date': '18', 'month': 'Apr', 'year': '2024', 'time': '03:14PM', 'timezone': 'UTC'}, '764696182', '741277471', 'bffr yes we do')
