# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# ...
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
hp = pd.read_csv("HPALL.csv", names=["id", "url"])

# %%
hp.shape
# Out:
# (283552, 2)

# %%
hp.drop_duplicates(["id"]).shape
# Out:
# (283552, 2)

# %%
hp1 = pd.read_csv("HPALL.csv", names=["id", "url"])
hp2 = pd.read_csv("HPALL2.csv", names=["id", "url"])
hp3 = pd.read_csv("HPALL3.csv", names=["id", "url"])

# %%
hp1.shape
# Out:
# (99990, 2)

# %%
hp2.shape
# Out:
# (61564, 2)

# %%
hp3.shape
# Out:
# (183493, 2)

# %%
hpall = pd.concat([hp1, hp2, hp3])

# %%
hpall
# Out:
#               id                                                url
# 0       10057010  https://archiveofourown.org/works?commit=Sort+...
# 1       14454174  https://archiveofourown.org/works?commit=Sort+...
# 2         234222  https://archiveofourown.org/works?commit=Sort+...
# 3       34500952  https://archiveofourown.org/works?commit=Sort+...
# 4       20049589  https://archiveofourown.org/works?commit=Sort+...
# ...          ...                                                ...
# 183488  34621429  https://archiveofourown.org/works/search?work_...
# 183489  34621204  https://archiveofourown.org/works/search?work_...
# 183490  34620367  https://archiveofourown.org/works/search?work_...
# 183491  34620352  https://archiveofourown.org/works/search?work_...
# 183492  34620148  https://archiveofourown.org/works/search?work_...
#
# [345047 rows x 2 columns]

# %%
hp1
# Out:
#              id                                                url
# 0      10057010  https://archiveofourown.org/works?commit=Sort+...
# 1      14454174  https://archiveofourown.org/works?commit=Sort+...
# 2        234222  https://archiveofourown.org/works?commit=Sort+...
# 3      34500952  https://archiveofourown.org/works?commit=Sort+...
# 4      20049589  https://archiveofourown.org/works?commit=Sort+...
# ...         ...                                                ...
# 99985   9579488  https://archiveofourown.org/works?commit=Sort+...
# 99986   9463145  https://archiveofourown.org/works?commit=Sort+...
# 99987   9438641  https://archiveofourown.org/works?commit=Sort+...
# 99988   9368570  https://archiveofourown.org/works?commit=Sort+...
# 99989  14043264  https://archiveofourown.org/works?commit=Sort+...
#
# [99990 rows x 2 columns]

# %%
pd.concat([hp1, hp2, hp3]).drop_duplicates().reset_index(drop=True)
# Out:
#               id                                                url
# 0       10057010  https://archiveofourown.org/works?commit=Sort+...
# 1       14454174  https://archiveofourown.org/works?commit=Sort+...
# 2         234222  https://archiveofourown.org/works?commit=Sort+...
# 3       34500952  https://archiveofourown.org/works?commit=Sort+...
# 4       20049589  https://archiveofourown.org/works?commit=Sort+...
# ...          ...                                                ...
# 345042  34621429  https://archiveofourown.org/works/search?work_...
# 345043  34621204  https://archiveofourown.org/works/search?work_...
# 345044  34620367  https://archiveofourown.org/works/search?work_...
# 345045  34620352  https://archiveofourown.org/works/search?work_...
# 345046  34620148  https://archiveofourown.org/works/search?work_...
#
# [345047 rows x 2 columns]
