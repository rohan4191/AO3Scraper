# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.1 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

# %%
hp = pd.read_csv("HPALL.csv", names=["id", "url"])
hp.shape
# Out:
# (283552, 2)

# %%
hp.drop_duplicates(subset=["id"], keep="first").shape
# Out:
# (283552, 2)

# %%
hp1 = pd.read_csv("HP1.csv", names=["id", "url"])
hp2 = pd.read_csv("HP2.csv", names=["id", "url"])
hp3 = pd.read_csv("HP3.csv", names=["id", "url"])
hp4 = pd.read_csv("HP4.csv", names=["id", "url"])
hp5 = pd.read_csv("HP5.csv", names=["id", "url"])
hpall = pd.read_csv("HPALL.csv", names=["id", "url"])

# %%
hp = pd.concat([hp1, hp2, hp3, hp4, hp5])

# %%
hp.shape
# Out:
# (475712, 2)

# %%
hp[hp.duplicated(["id"])]
# Out:
#              id                                                url
# 0      57725173  https://archiveofourown.org/works/search?work_...
# 1      57425455  https://archiveofourown.org/works/search?work_...
# 2      57418297  https://archiveofourown.org/works/search?work_...
# 3      57416251  https://archiveofourown.org/works/search?work_...
# 4      57413176  https://archiveofourown.org/works/search?work_...
# ...         ...                                                ...
# 62518  18746023  https://archiveofourown.org/works/search?work_...
# 62520  57748288  https://archiveofourown.org/works/search?work_...
# 62525  57765364  https://archiveofourown.org/works/search?work_...
# 62530  57598918  https://archiveofourown.org/works/search?work_...
# 62533  56677693  https://archiveofourown.org/works/search?work_...
#
# [7756 rows x 2 columns]

# %%
hp = hp.drop_duplicates(subset=["id"], keep="first")
hp.shape
# Out:
# (467956, 2)

# %%
hp.to_csv("HP.csv", index=False)
